# %% [markdown]
# # Setup

# %% [markdown]
# 📝 *Import required libraries and files:*

# %%
import pandas as pd
import numpy as np
from time import time

# 4.1. cleaning and preprocess
import re
from sklearn.feature_extraction.text import CountVectorizer, ENGLISH_STOP_WORDS

# 4.2. & 4.3. topic modeling
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from pathlib import Path
import json, joblib

# %%
path = r"C:\Users\pedro\OneDrive\Escritorio\Projetos\Banking APPs Reviews\3_df_sentiment.csv"
df_sentiment = pd.read_csv(path, low_memory=False)
print(f"df shape: {df_sentiment.shape}")
df_sentiment.head(2)
# Out:
# df shape: (813103, 20)
#    review_id           app  score  \
# 0          1  Santander UK      5
# 1          2  Santander UK      3
#
#                                          review_text  \
# 0           very easy to use app, very happy with it
# 1  New 2024 app is slow to open. Too much whitesp...
#
#                                    review_text_clean          review_date  \
# 0            very easy to use app very happy with it  2025-09-04 14:21:00
# 1  new 2024 app is slow to open too much whitespa...  2025-09-04 13:36:26
#
#    year  thumbs_up  replied  \
# 0  2025          0        1
# 1  2025          3        1
#
#                                           reply_text  \
# 0  Hi! Thanks for the 5* review, we're so glad to...
# 1  Hey there! All feedback is greatly appreciated...
#
#                                     reply_text_clean           reply_date  \
# 0  hi thanks for the 5 review were so glad to rea...  2025-09-04 14:40:12
# 1  hey there all feedback is greatly appreciated ...  2024-04-29 14:16:29
#
#    time_to_reply(h)  app_version_head app_version_detail  review_sentiment  \
# 0              0.32               5.0               24.0            0.8012
# 1         -11831.33               5.0               24.0           -0.8957
#
#   review_sentiment_label  Consistent  reply_sentiment reply_sentiment_label
# 0               positive           1           0.7761              positive
# 1               negative           1           0.8858              positive

# %% [markdown]
# # 4 - Topic Modeling

# %% [markdown]
# ## 4.1. - Model Training

# %% [markdown]
# The goal of this notebook is to identify frequent **pain points** mentioned by comments with negative reviews, as well as the **strenghts** addressed in positive reviews. We will focus on **user reviews** (i.e., discarting bank's replies) and we will **discart inconsistent cases** - e.g., reviews with negative scores but positive sentiment, or vice versa.
#
# We will work with a copy of `df_sentiment` and encapsulate all the transformations in the end to facilitate reproducibility.

# %%
df = df_sentiment.copy()

# %% [markdown]
# ### 4.1.1. - Text cleaning and preprocessing

# %% [markdown]
# Text cleaning and preprocessing is an essential step to get meaningful topics.
#
# First of all, all **inconsistent cases will be removed** - i.e., reviews with inconsistent score and sentiment.

# %%
print(f"Shape before removal of inconsistent cases: {df.shape}")

# Remove contradictory rows
df_model = df[df['Consistent']==1].copy()

print(f"Shape after of inconsistent cases: {df_model.shape}")
# Out:
# Shape before removal of inconsistent cases: (813103, 20)
# Shape after of inconsistent cases: (774649, 20)

# %% [markdown]
# Below we **perform text cleaning and preprocess**. A copy of original texts is kept in 'text' to allow later interpretation.

# %%
# Additional text cleaning / prior cleaning was already done in the cleaning function in notebook 2
def text_cleaner(x):
    if not isinstance(x, str):
        return pd.NA
    t = x
    t = re.sub(r'@\w+', ' ', t)                 # remove @mentions
    t = re.sub(r'\d+', ' <num> ', t)            # numbers -> <num>
    t = re.sub(r'[^a-z\s<>]+', ' ', t)          # keep letters, spaces, and <> so <num> survives
    t = re.sub(r'\s+', ' ', t).strip()          # normalize whitespace
    return t if t else pd.NA

# Apply cleaning
df_model['review_extra_clean'] = df_model['review_text_clean'].map(text_cleaner)

print(f"Shape after text_cleaner: {df_model.shape}")
# Out:
# Shape after text_cleaner: (774649, 21)

# %%
# Drop ultra-short reviews (fewer than 2 tokens)
df_model = df_model[df_model['review_extra_clean'].str.split().str.len() >= 2]

print(f"Shape after removing ultra-short reviews: {df_model.shape}")
# Out:
# Shape after removing ultra-short reviews: (674085, 21)

# %%
# Remove stop words --> words that can occur frequently but do not provide useful insight in the context of this analysis

# Domain stopwords
domain_sw = {
    'app','apps','bank','account','application', 'mobile', 'banks', 'santander', 'uk', 
    'lloyds', 'hsbc', 'revolut', 'barclays', 'monzo', 'banks', 'thanks', 'ive', 'num',
}

# Merge English + domain stopwords into a list
stop_words = list(ENGLISH_STOP_WORDS.union(domain_sw))

# %% [markdown]
# ### 4.1.2. - LDA trained with ALL reviews

# %% [markdown]
# We will use **LDA (Latent Dirichlet Allocation)** for topic modeling. LDA is a **generative probabilistic model** prepared to discover hidden topics in a colleciton of documents - i.e., our reviews in this case. In short, LDA defines topics according to word distribution, and then represents each document (i.e., review) as a probability distribution over those topics.

# %% [markdown]
# The following modeling **3-staged approach** will be used for LDA training and finetune:
# 1. Run LDA with 10 topics and evaluate top words for each of the 10 topics
# 2. Finetune 'stop words', removing top words that do not generate additional value, and re-run LDA
# 3. Test different `n` topics and Select best (i.e., more interpretable) number of topics and assign dominant topic for each review

# %% [markdown]
# **I. INITIAL RUN OF LDA WITH 10 TOPICS**

# %% [markdown]
# First of all, we'll **define functions** to build the vectorizer, run the LDA and print the results, to ensure future reproducibility.
#
# Note: For **vectorization** (i.e. transform text into a document-term matrix - DTM) we will use **Count Vectorizer Bag-of-Words** which is best **suited for LDA** (Latent Dirichlet Allocation) we inted to use in the next stage.

# %%
# Build vectorizer in case you've updated stopwords later
def build_vectorizer(stop_words, ngram_range=(1,2), min_df=20, max_df=0.5):
    return CountVectorizer(
        preprocessor=None,
        token_pattern=r'(?u)\b[a-z<][a-z<>-]{2,}\b',
        stop_words=stop_words,
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df
    )

# Run LDA
def fit_lda(X, n_topics=10, max_iter=10, random_state=42, n_jobs=-1):
    lda = LatentDirichletAllocation(
        n_components=n_topics,
        max_iter=max_iter,
        learning_method='batch',
        random_state=random_state,
        n_jobs=n_jobs
    )
    t0 = time()
    lda.fit(X)
    print(f"LDA fit done: {n_topics} topics in {time() - t0:.1f}s")
    return lda

# Print Top Words
def print_top_words(model, feature_names, n_top=12, title=None):
    if title:
        print(title)
    for t, comp in enumerate(model.components_):
        top_idx = comp.argsort()[-n_top:][::-1]
        print(f"Topic {t:02d}: " + " | ".join(feature_names[top_idx]))
    print()

# %% [markdown]
# Now we can run the model testing first for 10 topics.

# %%
# Build X for baseline run (10 topics)
vectorizer = build_vectorizer(stop_words)      
X = vectorizer.fit_transform(df_model['review_extra_clean'])
vocab = vectorizer.get_feature_names_out() # used later on to print top words

# %%
# Run LDA
lda_10 = fit_lda(X, n_topics=10)
# Out:
# LDA fit done: 10 topics in 1287.4s

# %% [markdown]
# Now let's see what are the top words for each topic:

# %%
print_top_words(lda_10, vocab, n_top=12)
# Out:
# Topic 00: easy | use | easy use | quick | simple | quick easy | great | secure | convenient | safe | great easy | fast
# Topic 01: banking | best | transfer | online | money | accounts | transfer money | online banking | great | check | day | manage
# Topic 02: phone | update | work | log | doesnt | love | working | just | doesnt work | use | screen | new
# Topic 03: just | dont | open | time | update | new | support | wont | customer | help | card | days
# Topic 04: great | money | far | card | amazing | exchange | nice | recommend | abroad | better | rates | using
# Topic 05: works | time | problems | love | great | just | using | lot | use | handy | banking | easier
# Topic 06: easy | payments | makes | card | easier | life | make | navigate | accounts | easy navigate | transfers | track
# Topic 07: good | like | really | fast | dont | pay | reliable | really good | efficient | service | good service | pretty
# Topic 08: useful | user | friendly | helpful | brilliant | user friendly | quick | really | straight | great | forward | use
# Topic 09: need | service | does | excellent | great | does need | awesome | excellent service | customer | fantastic | job | great service

# %% [markdown]
# As we can see from above there are still too many words that do not generate any additional value / insight that need to be removed (i.e., added to the stop words) in order not to polute the topic modeling and to extract meaningfull insights.

# %% [markdown]
# **II. Finetune stopwords and re-run LDA**

# %% [markdown]
# Adding new words that are poluting topics to `stop_words` --> 📌 this process was repeated for several times in this project.

# %%
domain_extra = {
    'able', 'absolutely', 'accounts', 'add', 'ago', 'alot', 'allows', 'amazing', 'anymore', 'appropriate','awesome', 'bad', 'banking', 
    'best', 'better', 'bit', 'branch', 'brilliant', 'business', 'change', 'cheque', 'cheques','clear', 'close', 'complicated', 
    'convenient', 'constantly', 'daily', 'date', 'day', 'days', 'definitely', 'did', 'didnt', 'different', 'difficult', 'does', 
    'doesnt', 'doing', 'dont', 'ease', 'easier', 'easily', 'easy', 'effective', 'efficient', 'especially', 'exactly', 'excellent', 
    'experience', 'extremely', 'fab', 'fantastic', 'far', 'fast', 'feels','finances', 'fine', 'fix', 'follow', 'forward', 'getting', 
    'gives', 'going', 'good', 'google', 'got', 'great', 'guys', 'handy', 'happy', 'havent', 'having', 'hassle', 'hello', 'helpful', 
    'helps', 'highly', 'hope', 'hoping', 'improved', 'isnt', 'issues', 'job', 'just','keeping', 'keeps', 'know', 'latest', 'let', 
    'lets', 'life', 'like', 'little', 'live', 'long', 'longer', 'lot', 'lots', 'love', 'loving','make', 'makes', 'making', 'month', 
    'months', 'need', 'needed', 'needs', 'neo', 'new', 'nice', 'number', 'old', 'online','open', 'overall', 'payees', 'pending', 
    'people', 'perfect', 'perfectly', 'place', 'pleased', 'poor', 'pretty', 'quick', 'quickly', 'quite', 'really', 'reason', 
    'recommend', 'recommended', 'reliable', 'rooted', 'round', 'rubbish', 'safe', 'satisfied', 'saves', 'say', 'says', 'set', 
    'simple', 'simpler', 'simply', 'slow', 'smooth', 'sort', 'star', 'stars', 'stopped', 'straighforward', 'straight', 
    'straightforward', 'stuff', 'super', 'superb', 'sure', 'takes', 'team', 'terrible', 'thank', 'thats', 'think', 'thing', 
    'things', 'time', 'times', 'tin', 'tried', 'try', 'trying', 'unable', 'understand', 'use', 'used', 'useful', 'useless', 
    'using', 'usually', 'want', 'way', 'website', 'went', 'whats', 'wish', 'wonderful', 'wont', 'work', 'worked', 'working', 'works', 
    'worst', 'wrong', 'years'
}

stop_words = list(set(stop_words).union(domain_extra))

# %% [markdown]
# Remove reviews that are exclusively stop words.

# %%
tmp_vec = CountVectorizer(
    preprocessor=None,
    token_pattern=r'(?u)\b[a-z<][a-z<>-]{2,}\b',
    stop_words=stop_words,
    ngram_range=(1,1)
)
analyze = tmp_vec.build_analyzer()

min_tokens_after_sw = 1
mask = df_model['review_extra_clean'].astype(str).map(lambda s: len(analyze(s)) >= min_tokens_after_sw)
print("Rows dropped after SW filter:", int((~mask).sum()))
df_model = df_model[mask].copy()
print(f"New df_model shape: {df_model.shape}")
# Out:
# Rows dropped after SW filter: 244629
# New df_model shape: (429456, 21)

# %%
vectorizer = build_vectorizer(stop_words)
X = vectorizer.fit_transform(df_model['review_extra_clean'])
vocab = vectorizer.get_feature_names_out()

# %% [markdown]
# **III. Test different `n_topics` and evaluate results**

# %% [markdown]
# In this stage, we will train several `n_topics` on a hold-out split

# %% [markdown]
# First, split once for fair model comparison.

# %%
X_train, X_valid = train_test_split(X, test_size=0.20, random_state=42)

# %% [markdown]
# Train a list of possible number of topics

# %%
candidate_topics = [5, 6, 7, 8, 9]  
lda_models = {}
rows = []

for k in candidate_topics:
    model = fit_lda(X_train, k)
    lda_models[k] = model
    rows.append({
        "k": k,
        "perplexity_train": model.perplexity(X_train),  # lower = better
        "perplexity_valid": model.perplexity(X_valid),  # lower = better
        "elbo_train": model.score(X_train),             # higher = better
        "elbo_valid": model.score(X_valid)              # higher = better
    })

metrics_df = pd.DataFrame(rows).sort_values("k").reset_index(drop=True)
display(metrics_df)
# Out:
# LDA fit done: 5 topics in 505.9s
# LDA fit done: 6 topics in 532.6s
# LDA fit done: 7 topics in 477.2s
# LDA fit done: 8 topics in 470.7s
# LDA fit done: 9 topics in 468.1s
#    k  perplexity_train  perplexity_valid    elbo_train    elbo_valid
# 0  5       2130.398874       2529.970917 -1.361503e+07 -3.453223e+06
# 1  6       2137.488375       2585.378165 -1.362094e+07 -3.462770e+06
# 2  7       2102.594600       2580.705062 -1.359170e+07 -3.461973e+06
# 3  8       2103.291954       2613.437580 -1.359229e+07 -3.467527e+06
# 4  9       2142.107303       2694.966802 -1.362477e+07 -3.481065e+06

# %% [markdown]
# Visual evaluation of validation perplexity

# %%
plt.plot(metrics_df["k"], metrics_df["perplexity_valid"], marker="o")
plt.xlabel("k (topics)")
plt.ylabel("Perplexity (validation)")
plt.title("LDA: validation perplexity vs k")
plt.show()

# %% [markdown]
# Check top words to manually evaluate best interpretability

# %%
for k in candidate_topics:
    print_top_words(lda_models[k], vocab, n_top=12, title=f"\n=== k={k} ===")
# Out:
# === k=5 ===
# Topic 00: service | card | features | customer | exchange | customer service | rates | abroad | currency | free | fees | travel
# Topic 01: update | user | friendly | user friendly | pay | log | phone | security | android | crashes | payment | contactless
# Topic 02: problems | navigate | transactions | balance | version | feature | transaction | log | fingerprint | login | functionality | previous
# Topic 03: money | transfer | secure | payments | check | manage | transfer money | pay | track | send | bills | transfers
# Topic 04: phone | access | support | help | chat | issue | problem | details | screen | code | contact | security
#
#
# === k=6 ===
# Topic 00: service | card | exchange | customer | customer service | features | rates | abroad | currency | free | fees | travel
# Topic 01: update | user | friendly | user friendly | pay | log | phone | android | crashes | updated | contactless | crashing
# Topic 02: problems | navigate | payment | transfers | login | fingerprint | balance | log | transaction | fault | feature | functionality
# Topic 03: money | transfer | secure | check | manage | transfer money | pay | payments | track | send | bills | balance
# Topic 04: phone | support | access | help | chat | details | problem | code | screen | issue | customer | contact
# Topic 05: transactions | problem | payments | intuitive | features | direct | version | available | previous | view | updates | control
#
#
# === k=7 ===
# Topic 00: service | customer | exchange | card | customer service | rates | abroad | currency | free | fees | travel | features
# Topic 01: update | log | phone | pay | android | crashes | updated | contactless | error | crashing | security | load
# Topic 02: problems | navigate | transfers | fingerprint | login | balance | version | functionality | transaction | paying | feature | design
# Topic 03: money | transfer | secure | check | pay | manage | transfer money | payments | track | send | bills | balance
# Topic 04: phone | support | help | chat | details | access | code | problem | contact | screen | issue | password
# Topic 05: transactions | payments | problem | features | intuitive | direct | control | view | available | balance | updates | finger
# Topic 06: card | user | friendly | user friendly | payment | credit | cards | access | interface | credit card | options | fault
#
#
# === k=8 ===
# Topic 00: service | exchange | customer | customer service | card | rates | abroad | currency | free | fees | travel | rate
# Topic 01: update | log | phone | pay | android | crashes | updated | contactless | error | crashing | version | samsung
# Topic 02: problems | navigate | transfers | balance | functionality | transaction | feature | issue | payments | design | international | functional
# Topic 03: money | transfer | secure | check | manage | pay | transfer money | send | payments | track | bills | save
# Topic 04: phone | support | chat | help | customer | problem | contact | screen | details | issue | lost | access
# Topic 05: transactions | payments | problem | intuitive | features | direct | control | version | view | previous | updates | finger
# Topic 06: card | user | friendly | user friendly | payment | credit | cards | credit card | options | fault | notifications | cool
# Topic 07: security | access | services | fingerprint | paying | secure | help | login | interface | feel | internet | code
#
#
# === k=9 ===
# Topic 00: service | exchange | customer | card | customer service | rates | abroad | currency | free | fees | travel | rate
# Topic 01: update | log | phone | pay | android | crashes | updated | contactless | error | crashing | version | annoying
# Topic 02: problems | navigate | transfers | functionality | balance | design | feature | world | functional | issue | impressed | payments
# Topic 03: money | transfer | secure | check | manage | transfer money | pay | payments | send | track | bills | balance
# Topic 04: phone | support | chat | help | screen | customer | contact | problem | issue | password | details | access
# Topic 05: transactions | problem | features | payments | intuitive | control | version | previous | balance | updates | layout | view
# Topic 06: card | user | friendly | user friendly | payment | interface | cards | options | fault | notifications | cool | virtual
# Topic 07: security | access | services | fingerprint | help | paying | secure | login | internet | available | statements | code
# Topic 08: transaction | credit | direct | card | lost | option | credit card | payments | standing | debits | finger | direct debits

# %% [markdown]
# **✅ RUN SELECTED MODEL AND SAVE RESULTS**

# %% [markdown]
# When we analyse the key words for each `k` for the number of topics it is clear that lower number of topics generate more coherent topics than when we use higher `k`. Given the validation perplexity scores and their interpretation, we selct **7 topics as the optimal choice** for the best LDA.

# %%
chosen_k = 7

# Train model with selected parameters
lda_best = fit_lda(X, n_topics=chosen_k)
# Out:
# LDA fit done: 7 topics in 621.1s

# %%
# print topics for k=7
print_top_words(lda_best, vocab, n_top=12)
# Out:
# Topic 00: service | customer | exchange | card | customer service | rates | abroad | currency | free | features | fees | travel
# Topic 01: update | log | phone | pay | android | crashes | updated | contactless | error | load | crashing | security
# Topic 02: problems | navigate | transfers | fingerprint | balance | login | version | functionality | feature | issue | design | payments
# Topic 03: money | transfer | secure | check | pay | manage | transfer money | send | bills | track | payments | balance
# Topic 04: phone | support | help | chat | details | access | contact | code | problem | screen | password | issue
# Topic 05: transactions | payments | problem | intuitive | features | control | direct | view | finger | updates | standing | layout
# Topic 06: card | user | friendly | user friendly | payment | credit | cards | interface | access | credit card | transaction | options

# %%
# Save
joblib.dump(lda_best, "../assets/lda_final_ALL.pkl")
joblib.dump(vectorizer, "../assets/vectorizer_final_ALL.pkl")
print("✅ Files saved")
# Out:
# ✅ Files saved

# %% [markdown]
# ### 4.1.3. - LDA trained with NEGATIVE reviews only

# %% [markdown]
# Let's now **train a LDA model exclusively on reviews with negative sentiment** so that we can **extract more meaningfull insights** regarding **pain points** on each app.

# %%
df_neg = df_model[df_model['review_sentiment_label'] == 'negative'].copy()

print(f"df_model shape: {df_model.shape}")
print(f"df_neg shape: {df_neg.shape}")
# Out:
# df_model shape: (429456, 21)
# df_neg shape: (58915, 21)

# %% [markdown]
# **I. INITIAL RUN OF LDA WITH 10 TOPICS**

# %%
vectorizer_neg = build_vectorizer(stop_words)
X_neg = vectorizer_neg.fit_transform(df_neg['review_extra_clean'])
vocab_neg = vectorizer_neg.get_feature_names_out()

lda_neg_10 = fit_lda(X_neg, n_topics=10)
print_top_words(lda_neg_10, vocab, n_top=12, title ="Top words @ 10 topics")
# Out:
# LDA fit done: 10 topics in 109.5s
# Top words @ 10 topics
# Topic 00: access transfer | farce | fees card | disgrace | dissatisfied | currencies travel | council tax | card metal | barcleys | costing | expiring | assets
# Topic 01: download install | backgrounds | backs | copies | aplikacja | attempts | council tax | crash | countries currency | advert | card today | charge
# Topic 02: farce | crash | currency payments | bloody | disabling | features coming | commissions | big update | fintech company | deleted | fails load | classic
# Topic 03: errors | copies | advising | complain | appears | expiring | expiry | adopt | aint broke | encounter | encanta | card paid
# Topic 04: classic | convinced | considering | available samsung | chosen | apt | captured | access transfer | disgrace | create virtual | click button | enter pin
# Topic 05: access personal | farce | crash | basic card | bugs fixed | click button | direct feature | basic functionality | features exchange | crashing login | avoid avoid | card block
# Topic 06: ability view | bloody | barcleys | bla | apt | crash | card paid | commissions | aplikacja | double | classic | commodities
# Topic 07: android tablet | features transactions | award | copies | annoying frustrating | annual | aware | card lose | complain | capable | expire | budget save
# Topic 08: complain | expiry | clumsy | allow login | explaining | domestic | adult | cancel direct | awful awful | card asked | disappointed update | asia
# Topic 09: current exchange | beautifully | finally updated | balance away | ability view | countries currency | employed | crashing pay | changed log | balance moving | coin | covering

# %% [markdown]
# **II. Finetune stopwords and re-run LDA**

# %%
neg_extra = {
    'abd','abit','according','address','anoying','annoying','approximately','appit',
    'applies','arbitrary','arise','aspects','awful','awhile','awkward','bare','bardzo',
    'barclaycard','based','basis','banki','began','begin','believe','barely',
    'bloody','boys','buys','centres','consider','constantly','continue','continually',
    'contrary','cool','corporate','cos','couple','covered','damn','dave','dear',
    'decades','dedicated','depend','der','des','difficult','die','dinosaur',
    'dirty','dislike','dosnt','email','exist','faced','fairly','firstly','fix',
    'frustrating','fyi','goto','half','hanging','hate','heavy','heard', 'infuriating',
    'minutes','poor','saying','waste','hello','worse','wouldnt'
}

stop_words_neg = list(set(stop_words).union(neg_extra))

# %%
vectorizer_neg = build_vectorizer(stop_words_neg, ngram_range=(1,2), min_df=25, max_df=0.6)
X_neg = vectorizer_neg.fit_transform(df_neg['review_extra_clean'])
vocab_neg = vectorizer_neg.get_feature_names_out()

# %%
tmp_vec = CountVectorizer(
    preprocessor=lambda x: x,
    token_pattern=r'(?u)\b[a-z<][a-z<>-]{2,}\b',
    stop_words=stop_words_neg,
    ngram_range=(1,1)
)
analyze = tmp_vec.build_analyzer()

min_tokens_after_sw = 1
mask = df_neg['review_extra_clean'].map(lambda s: len(analyze(s)) >= min_tokens_after_sw)
print("Dropped after SW-length filter:", int((~mask).sum()))
df_neg = df_neg[mask].copy()
# Out:
# Dropped after SW-length filter: 342

# %% [markdown]
# **III. Test different `n_topics` and evaluate results**

# %%
Xtr, Xva = train_test_split(X_neg, test_size=0.2, random_state=42)

# %%
candidate_negtopics = [4,5,6,7,8]
lda_models, rows = {}, []

for k in candidate_negtopics:
    model = fit_lda(Xtr, k)
    lda_models[k]=model
    rows.append({
        "k": k,
        "perplexity_train": model.perplexity(Xtr),  # lower = better
        "perplexity_valid": model.perplexity(Xva),  # lower = better
        "elbo_train": model.score(Xtr),             # higher = better
        "elbo_valid": model.score(Xva)              # higher = better
    })

neg_metrics_df = pd.DataFrame(rows).sort_values("k").reset_index(drop=True)
display(neg_metrics_df)
# Out:
# LDA fit done: 4 topics in 98.8s
# LDA fit done: 5 topics in 93.8s
# LDA fit done: 6 topics in 92.1s
# LDA fit done: 7 topics in 89.5s
# LDA fit done: 8 topics in 86.5s
#    k  perplexity_train  perplexity_valid    elbo_train     elbo_valid
# 0  4       1208.547933       1464.296445 -2.675245e+06 -691607.248207
# 1  5       1222.242746       1532.968721 -2.679492e+06 -695955.814640
# 2  6       1235.813579       1597.398345 -2.683654e+06 -699862.113785
# 3  7       1250.305954       1664.827782 -2.688049e+06 -703785.049180
# 4  8       1238.601040       1691.338722 -2.684503e+06 -705284.059056

# %%
plt.plot(neg_metrics_df["k"], neg_metrics_df["perplexity_valid"], marker="o")
plt.xlabel("k (topics)")
plt.ylabel("Perplexity (validation)")
plt.title("LDA: validation perplexity vs k")
plt.show()

# %%
for k in candidate_negtopics:
    print_top_words(lda_models[k], vocab_neg, n_top=12, title=f"\n=== k={k} ===")
# Out:
# === k=4 ===
# Topic 00: phone | update | log | access | login | code | android | screen | problem | updated | version | crashes
# Topic 01: pay | card | payments | payment | contactless | user | transactions | paying | lost | update | option | features
# Topic 02: error | update | balance | message | problem | problems | notifications | issue | direct | check | download | available
# Topic 03: money | service | customer | transfer | card | customer service | support | chat | help | contact | blocked | access
#
#
# === k=5 ===
# Topic 00: phone | log | update | access | code | login | password | fingerprint | details | device | security | updated
# Topic 01: pay | card | payments | payment | contactless | lost | paying | transactions | credit | feature | cards | photo
# Topic 02: update | error | screen | balance | message | notifications | problems | log | transactions | check | problem | direct
# Topic 03: money | service | customer | transfer | customer service | chat | support | card | help | contact | blocked | access
# Topic 04: version | problem | update | android | money | user | pay | stop | support | fees | phone | samsung
#
#
# === k=6 ===
# Topic 00: phone | log | update | access | login | code | password | fingerprint | updated | device | details | security
# Topic 01: pay | payments | card | payment | contactless | problems | paying | lost | transactions | updates | crashing | credit
# Topic 02: update | error | screen | balance | message | notifications | log | transactions | check | direct | page | view
# Topic 03: money | transfer | chat | blocked | help | access | transfer money | funds | contact | fraud | block | scam
# Topic 04: version | problem | update | android | user | fees | phone | stop | previous | upgrade | pay | confusing
# Topic 05: service | customer | card | customer service | support | chat | hours | verify | verification | issue | send | help
#
#
# === k=7 ===
# Topic 00: phone | update | log | access | password | updated | login | android | fingerprint | code | screen | pin
# Topic 01: pay | payments | payment | contactless | card | lost | paying | transactions | feature | updates | features | crashing
# Topic 02: update | notifications | screen | balance | transactions | view | direct | option | download | page | list | payment
# Topic 03: money | transfer | chat | help | blocked | access | transfer money | contact | fraud | funds | support | problem
# Topic 04: pay | version | problem | user | android | support | fees | money | exchange | crypto | rate | previous
# Topic 05: service | customer | card | customer service | support | chat | hours | verify | verification | send | money | asked
# Topic 06: error | problems | details | log | message | update | issue | code | crashes | device | login | problem
#
#
# === k=8 ===
# Topic 00: phone | update | log | android | updated | access | fingerprint | problem | password | login | screen | uninstalled
# Topic 01: pay | payments | payment | contactless | card | paying | updates | transactions | crashing | feature | functionality | features
# Topic 02: update | screen | balance | notifications | transactions | view | page | direct | download | list | statements | home
# Topic 03: money | transfer | access | blocked | transfer money | payment | pay | card | fraud | funds | block | transaction
# Topic 04: version | user | update | pay | fees | stop | previous | confusing | upgrade | crypto | exchange | rate
# Topic 05: card | code | send | security | verify | phone | verification | process | details | pin | information | accept
# Topic 06: error | problems | log | details | message | update | login | issue | device | credit | reinstall | problem
# Topic 07: service | customer | customer service | support | chat | help | lost | contact | money | problem | card | hours

# %% [markdown]
# **✅ RUN SELECTED MODEL AND SAVE RESULTS**

# %%
chosen_k_neg = 6

lda_best_neg = fit_lda(X_neg, n_topics=chosen_k_neg)

print_top_words(lda_best_neg, vocab_neg, 12)
# Out:
# LDA fit done: 6 topics in 115.2s
# Topic 00: phone | log | update | access | code | login | password | fingerprint | updated | device | security | details
# Topic 01: pay | payments | card | payment | contactless | problems | lost | paying | transactions | feature | credit | crashing
# Topic 02: update | error | screen | message | balance | notifications | log | page | download | direct | problem | transactions
# Topic 03: money | transfer | blocked | access | transfer money | help | funds | fraud | transaction | send | payment | block
# Topic 04: version | problem | user | update | android | fees | pay | previous | upgrade | crypto | exchange | confusing
# Topic 05: service | customer | card | customer service | support | chat | hours | contact | help | verify | verification | issue

# %%
# Save
joblib.dump(lda_best_neg, "../assets/lda_final_NEG.pkl")
joblib.dump(vectorizer_neg, "../assets/vectorizer_final_NEG.pkl")
print("✅ Files saved")
# Out:
# ✅ Files saved

# %% [markdown]
# ### 4.1.4. - LDA trained with POSITIVE reviews only

# %% [markdown]
# Finally we'll **train a LDA model exclusively on reviews with positive sentiment** so that we can **extract more meaningfull insights** regarding **strenghts** on each app.

# %%
df_pos = df_model[df_model['review_sentiment_label'] == 'positive'].copy()

print(f"df_model shape: {df_model.shape}")
print(f"df_neg shape: {df_pos.shape}")
# Out:
# df_model shape: (429456, 21)
# df_neg shape: (309006, 21)

# %% [markdown]
# **I. INITIAL RUN OF LDA WITH 10 TOPICS**

# %%
vectorizer_pos = build_vectorizer(stop_words)
X_pos = vectorizer_pos.fit_transform(df_pos['review_extra_clean'])
vocab_pos = vectorizer_pos.get_feature_names_out()

lda_pos_10 = fit_lda(X_pos, n_topics=10)
print_top_words(lda_pos_10, vocab_pos, n_top=12, title ="Top words @ 10 topics")
# Out:
# LDA fit done: 10 topics in 399.2s
# Top words @ 10 topics
# Topic 00: abroad | balance | money | free | currency | transferring | check | spending | feel | transferring money | fees | check balance
# Topic 01: problem | services | intuitive | paying | crypto | save | credit | cool | saving | layout | financial | credit card
# Topic 02: card | money | manage | transactions | rate | exchange | check | send | cards | currencies | send money | payments
# Topic 03: transfer | money | access | rates | transfer money | track | transfers | exchange | exchange rates | help | friends | family
# Topic 04: features | options | cash | managing | transactions | card | travelling | world | tool | notifications | site | wouldnt
# Topic 05: update | phone | log | payment | screen | android | updated | version | crashes | payee | contactless | load
# Topic 06: service | secure | navigate | customer | customer service | direct | interface | functionality | complaints | debits | direct debits | clean
# Topic 07: support | help | security | issue | fingerprint | transaction | chat | customer | login | option | contact | lost
# Topic 08: user | friendly | pay | user friendly | bills | everyday | internet | pay bills | interface | money | moving | gets
# Topic 09: problems | payments | security | control | fault | international | transfers | information | transactions | standing | staff | lovely

# %% [markdown]
# **II. Finetune stopwords and re-run LDA**

# %%
pos_extra = {'lovely'} #

stop_words_pos = list(set(stop_words).union(pos_extra))

# %%
vectorizer_pos = build_vectorizer(stop_words_pos, ngram_range=(1,2), min_df=25, max_df=0.6)
X_pos = vectorizer_pos.fit_transform(df_pos['review_extra_clean'])
vocab_pos = vectorizer_pos.get_feature_names_out()

# %%
tmp_vec = CountVectorizer(
    preprocessor=lambda x: x,
    token_pattern=r'(?u)\b[a-z<][a-z<>-]{2,}\b',
    stop_words=stop_words_pos,
    ngram_range=(1,1)
)
analyze = tmp_vec.build_analyzer()

min_tokens_after_sw = 1
mask = df_pos['review_extra_clean'].map(lambda s: len(analyze(s)) >= min_tokens_after_sw)
print("Dropped after SW-length filter:", int((~mask).sum()))
df_pos = df_pos[mask].copy()
# Out:
# Dropped after SW-length filter: 475

# %% [markdown]
# **III. Test different `n_topics` and evaluate results**

# %%
Xtr, Xva = train_test_split(X_pos, test_size=0.2, random_state=42)

# %%
candidate_postopics = [4,5,6,7,8]
lda_models, rows = {}, []

for k in candidate_postopics:
    model = fit_lda(Xtr, k)
    lda_models[k]=model
    rows.append({
        "k": k,
        "perplexity_train": model.perplexity(Xtr),  # lower = better
        "perplexity_valid": model.perplexity(Xva),  # lower = better
        "elbo_train": model.score(Xtr),             # higher = better
        "elbo_valid": model.score(Xva)              # higher = better
    })

pos_metrics_df = pd.DataFrame(rows).sort_values("k").reset_index(drop=True)
display(pos_metrics_df)
# Out:
# LDA fit done: 4 topics in 368.6s
# LDA fit done: 5 topics in 343.2s
# LDA fit done: 6 topics in 331.5s
# LDA fit done: 7 topics in 321.7s
# LDA fit done: 8 topics in 317.8s
#    k  perplexity_train  perplexity_valid    elbo_train    elbo_valid
# 0  4       1474.858983       1687.333089 -7.821864e+06 -1.992025e+06
# 1  5       1447.007410       1680.350932 -7.801426e+06 -1.990913e+06
# 2  6       1428.781425       1683.812163 -7.787837e+06 -1.991465e+06
# 3  7       1424.883879       1703.052515 -7.784909e+06 -1.994511e+06
# 4  8       1430.764679       1735.663159 -7.789324e+06 -1.999595e+06

# %%
plt.plot(pos_metrics_df["k"], pos_metrics_df["perplexity_valid"], marker="o")
plt.xlabel("k (topics)")
plt.ylabel("Perplexity (validation)")
plt.title("LDA: validation perplexity vs k")
plt.show()

# %%
for k in candidate_postopics:
    print_top_words(lda_models[k], vocab_pos, n_top=12, title=f"\n=== k={k} ===")
# Out:
# === k=4 ===
# Topic 00: service | card | user | friendly | user friendly | navigate | exchange | rates | abroad | currency | travel | credit
# Topic 01: features | security | problem | transactions | manage | log | control | update | payment | fingerprint | login | screen
# Topic 02: money | secure | transfer | payments | check | pay | transfers | access | transfer money | balance | track | spending
# Topic 03: problems | phone | update | customer | support | services | free | help | pay | issue | customer service | crypto
#
#
# === k=5 ===
# Topic 00: service | user | friendly | user friendly | navigate | customer | customer service | manage | fault | internet | financial | travelling
# Topic 01: features | security | problem | transactions | log | fingerprint | control | login | manage | screen | payment | update
# Topic 02: money | transfer | check | access | balance | pay | transfer money | payments | track | spending | bills | options
# Topic 03: problems | phone | update | support | help | services | issue | android | crypto | customer | interface | pay
# Topic 04: card | secure | money | exchange | payments | abroad | rates | currency | transfers | travel | free | credit
#
#
# === k=6 ===
# Topic 00: service | user | friendly | user friendly | navigate | customer | customer service | fault | internet | security | faster | responsive
# Topic 01: features | transactions | manage | security | problem | control | log | fingerprint | feature | feel | payee | option
# Topic 02: money | secure | transfer | check | transfer money | balance | payments | track | pay | spending | bills | transferring
# Topic 03: problems | services | pay | crypto | interface | free | money | high | transaction | send | trading | buy
# Topic 04: card | money | exchange | payments | abroad | rates | currency | transfers | travel | credit | rate | friends
# Topic 05: phone | update | help | access | support | issue | log | information | android | updated | version | chat
#
#
# === k=7 ===
# Topic 00: service | user | friendly | user friendly | customer | customer service | fault | internet | faster | security | responsive | line
# Topic 01: transactions | features | manage | security | problem | control | log | fingerprint | manage money | feature | payee | finger
# Topic 02: money | secure | transfer | check | transfer money | balance | track | spending | pay | bills | payments | transferring
# Topic 03: problems | services | pay | free | crypto | money | interface | send | high | buy | trading | stocks
# Topic 04: card | payments | money | abroad | credit | friends | save | pay | payment | cash | cards | direct
# Topic 05: update | phone | access | help | support | issue | log | version | android | information | updated | chat
# Topic 06: navigate | exchange | rates | currency | transfers | rate | travelling | currencies | exchange rates | travel | fees | instant
#
#
# === k=8 ===
# Topic 00: service | user | friendly | user friendly | internet | faster | line | financial | wouldnt | responsive | design | security
# Topic 01: transactions | features | manage | security | problem | control | feel | manage money | feature | log | finger | home
# Topic 02: money | secure | transfer | check | transfer money | balance | track | spending | pay | bills | payments | transferring
# Topic 03: problems | pay | money | services | send | crypto | interface | send money | high | staff | buy | stocks
# Topic 04: card | payments | money | abroad | credit | friends | save | cash | pay | direct | credit card | intuitive
# Topic 05: update | phone | access | log | android | version | information | updated | login | help | screen | crashes
# Topic 06: navigate | exchange | rates | currency | transfers | rate | travelling | currencies | travel | exchange rates | fees | instant
# Topic 07: customer | support | service | customer service | help | free | chat | payment | fault | issue | year | lost

# %% [markdown]
# **✅ RUN SELECTED MODEL AND SAVE RESULTS**

# %%
chosen_k_pos = 6

lda_best_pos = fit_lda(X_pos, n_topics=chosen_k_pos)

print_top_words(lda_best_pos, vocab_pos, 12)
# Out:
# LDA fit done: 6 topics in 423.7s
# Topic 00: service | user | friendly | user friendly | navigate | customer | customer service | fault | security | internet | faster | responsive
# Topic 01: features | transactions | manage | security | problem | control | log | feature | feel | fingerprint | payee | option
# Topic 02: money | secure | transfer | check | transfer money | balance | payments | track | pay | spending | bills | transferring
# Topic 03: problems | services | pay | crypto | free | high | transaction | customer | trading | customers | staff | stocks
# Topic 04: card | money | exchange | payments | abroad | rates | transfers | currency | travel | rate | credit | friends
# Topic 05: phone | update | help | access | support | issue | log | version | updated | android | information | chat

# %%
# Save
joblib.dump(lda_best_pos, "../assets/lda_final_POS.pkl")
joblib.dump(vectorizer_pos, "../assets/vectorizer_final_POS.pkl")
print("✅ Files saved")
# Out:
# ✅ Files saved

# %% [markdown]
# ## 4.2. - Model Deployment

# %% [markdown]
# In section 4.1., three LDA models were trained: i) lda_ALL trained on all type of reviews; 2) lda_NEG trained on negative reviews only; 3) lda_POS trained on positive reviews only. Now we will transform the original dataframe we had at the beggining of this notebook using the 3 selected LDAs and assigning the corresponding topic labels for each review and model. All the transformations are encapsulated inside `apply_ldas` to facilitate reproducibility.

# %%
def apply_ldas(
    df: pd.DataFrame,
    text_col: str = "review_text_clean",
    # generic model (trained on all reviews)
    lda_path: str = "../assets/lda_final_ALL.pkl",
    vect_path: str = "../assets/vectorizer_final_ALL.pkl",
    # negative-only model
    lda_neg_path: str = "../assets/lda_final_NEG.pkl",
    vect_neg_path: str = "../assets/vectorizer_final_NEG.pkl",
    # positive-only model
    lda_pos_path: str = "../assets/lda_final_POS.pkl",
    vect_pos_path: str = "../assets/vectorizer_final_POS.pkl",
    inplace: bool = True,
) -> pd.DataFrame:
    """
    Append 9 columns using three LDA models:
      Generic: topic_id_ALL, topic_label_ALL, topic_prob_ALL
      Negative-only (score in {1,2}): topic_id_NEG, topic_label_NEG, topic_prob_NEG
      Positive-only (score in {4,5}): topic_id_POS, topic_label_POS, topic_prob_POS
    """
    if not inplace:
        df = df.copy()

    print(f"Initial shape of the dataframe: {df.shape}")

    # --- Text cleaning ----------------------------------------------------
    def text_cleaner(x):
        if not isinstance(x, str):
            return pd.NA
        t = x
        t = re.sub(r"@\w+", " ", t)                  # remove @mentions
        t = re.sub(r"\d+", " <num> ", t)             # numbers -> <num>
        t = re.sub(r"[^a-z\s<>]+", " ", t)           # keep letters, spaces, and <> so <num> survives
        t = re.sub(r"\s+", " ", t).strip()           # normalize whitespace
        return t if t else pd.NA

    df["review_extra_clean"] = df[text_col].map(text_cleaner)   

    if text_col not in df.columns:
        raise KeyError(f"Column '{text_col}' not found.")

    s = df[text_col].astype("string")  # NA-safe string Series

    # ----------------- helper -----------------
    def _apply_one(lda, vect, mask_rows, label_map, col_suffix, nan_outside_mask: bool):
        """
        lda, vect: fitted artifacts
        mask_rows: boolean mask of rows to consider for this model
        label_map: dict[int,str] mapping topic id -> label
        col_suffix: '_ALL', '_NEG', or '_POS'
        nan_outside_mask:
            - True  -> rows outside mask get NaN in all 3 columns (for neg/pos models)
            - False -> rows outside eligibility get Undefined/-1/0.0 (for generic model)
        """
        if not hasattr(vect, "transform"):
            raise TypeError("Loaded vectorizer has no .transform()")

        # Eligibility rules
        analyzer = vect.build_analyzer()
        
        sw_ok = s.fillna("").map(lambda t: len(analyzer(t)) >= 1)
        consistent_ok = df["Consistent"].fillna(0).astype(int).eq(1)

        elig = mask_rows & sw_ok & consistent_ok

        # Prepare outputs
        if nan_outside_mask:
            # For neg/pos models we keep NaN outside the score mask
            topic_id = pd.Series(np.nan, index=df.index, dtype="float")
            topic_prob = pd.Series(np.nan, index=df.index, dtype="float")
            topic_label = pd.Series(np.nan, index=df.index, dtype="string")
        else:
            # For generic model, fill with Undefined defaults when ineligible
            topic_id = pd.Series(-1, index=df.index, dtype="int64")
            topic_prob = pd.Series(0.0, index=df.index, dtype="float64")
            topic_label = pd.Series("Undefined", index=df.index, dtype="string")

        # Vectorize eligible subset
        if elig.any():
            X = vect.transform(s[elig].fillna(""))

            # Rule 3: drop zero-feature rows (OOV)
            zero = np.array(X.sum(axis=1)).ravel() == 0
            if zero.any():
                bad_idx = s[elig].index[zero]
                elig.loc[bad_idx] = False
                if elig.any():
                    X = vect.transform(s[elig].fillna(""))

            # Score eligible
            if elig.any():
                D = lda.transform(X)                       # (n_docs_elig, n_topics)
                ti = D.argmax(axis=1)
                tp = D.max(axis=1)

                topic_id.loc[elig] = ti
                topic_prob.loc[elig] = tp
                topic_label.loc[elig] = pd.Series(ti, index=df[elig].index).map(
                    lambda k: label_map.get(int(k), "Undefined")
                ).astype("string")

        # Attach to df
        df[f"topic_id{col_suffix}"] = topic_id
        df[f"topic_label{col_suffix}"] = topic_label
        df[f"topic_prob{col_suffix}"] = topic_prob

    # ----------------- load artifacts -----------------
    lda_all = joblib.load(lda_path)
    vect_all = joblib.load(vect_path)
    lda_neg = joblib.load(lda_neg_path)
    vect_neg = joblib.load(vect_neg_path)
    lda_pos = joblib.load(lda_pos_path)
    vect_pos = joblib.load(vect_pos_path)

    # ----------------- label maps (edit to your final names) -----------------
    labels_gen = {
        0: "Fees & Service & Travel",
        1: "Updates, Crashes & Performance",
        2: "Login, Navigation & Functionality Issues",
        3: "Money Transfers & Payment Management",
        4: "Support & Access",
        5: "Transactions, Features & Usability",
        6: "Cards & Payments",
    } 
    labels_neg = {
        0: "Login & Security",
        1: "Payments & Cards",
        2: "App Updates & Crashes",
        3: "Transfers & Transaction",
        4: "Interface, Features & Fees",
        5: "Customer Service & Support",
    }
    # Stub/default for positive model – adjust to your pos-only training labels
    labels_pos = {
        0: "Customer Service & Usability",
        1: "Features, Security, Transactions",
        2: "Payments, Transfers & Money Mgmt",
        3: "Investments",
        4: "Cards & Travel",
        5: "Updates & Support",
    }

    # ----------------- run all three -----------------
    # Generic: run for everyone; ineligible -> Undefined/-1/0.0
    _apply_one(lda_all, vect_all, mask_rows=pd.Series(True, index=df.index), label_map=labels_gen,
               col_suffix="_ALL", nan_outside_mask=False)

    # Negative-only: only when score ∈ {1,2}; outside mask stays NaN
    _apply_one(lda_neg, vect_neg, mask_rows=df["score"].isin([1, 2]), label_map=labels_neg,
               col_suffix="_NEG", nan_outside_mask=True)

    # Positive-only: only when score ∈ {4,5}; outside mask stays NaN
    _apply_one(lda_pos, vect_pos, mask_rows=df["score"].isin([4, 5]), label_map=labels_pos,
               col_suffix="_POS", nan_outside_mask=True)

    # Order columns: keep original order, then append all new columns
    tail = [
        "topic_id_ALL", "topic_label_ALL", "topic_prob_ALL",
        "topic_id_NEG", "topic_label_NEG", "topic_prob_NEG",
        "topic_id_POS", "topic_label_POS", "topic_prob_POS",
    ]
    base = [c for c in df.columns if c not in tail]
    df = df[base + tail]

    print(f"Final shape of the dataframe: {df.shape}")

    # --- Save Final Dataframe ---
    save_path = "../assets/df_final.parquet"
    df.to_parquet(save_path, index = False)
    print(f"✅ Dataframe saved in {save_path}")

    return df

# %%
df_final = apply_ldas (df_sentiment)
# Out:
# Initial shape of the dataframe: (813103, 20)
# Final shape of the dataframe: (813103, 30)
# ✅ Dataframe saved in ../assets/df_final.parquet

# %%
pd.set_option("display.max_columns", None)
df_final.head(10)
# Out:
#    review_id           app  score  \
# 0          1  Santander UK      5
# 1          2  Santander UK      3
# 2          3  Santander UK      5
# 3          4  Santander UK      2
# 4          5  Santander UK      5
# 5          6  Santander UK      5
# 6          7  Santander UK      3
# 7          8  Santander UK      3
# 8          9  Santander UK      4
# 9         10  Santander UK      5
#
#                                          review_text  \
# 0           very easy to use app, very happy with it
# 1  New 2024 app is slow to open. Too much whitesp...
# 2                              easy to use.. Great..
# 3          having issues with your updates .. advice
# 4                                     so easy to use
# 5                                              Easy.
# 6  it would be a lot better if the balance widget...
# 7  Having changed a savings account name (which w...
# 8  They put the widget back! All is right with th...
# 9                                        Easy to use
#
#                                    review_text_clean          review_date  \
# 0            very easy to use app very happy with it  2025-09-04 14:21:00
# 1  new 2024 app is slow to open too much whitespa...  2025-09-04 13:36:26
# 2                                  easy to use great  2025-09-04 13:27:27
# 3             having issues with your updates advice  2025-09-04 13:26:24
# 4                                     so easy to use  2025-09-04 12:37:14
# 5                                               easy  2025-09-04 10:25:54
# 6  it would be a lot better if the balance widget...  2025-09-04 09:19:42
# 7  having changed a savings account name which wa...  2025-09-04 09:19:39
# 8  they put the widget back all is right with the...  2025-09-04 09:08:17
# 9                                        easy to use  2025-09-04 08:59:20
#
#    year  thumbs_up  replied  \
# 0  2025          0        1
# 1  2025          3        1
# 2  2025          0        1
# 3  2025          0        1
# 4  2025          0        1
# 5  2025          0        1
# 6  2025          0        1
# 7  2025          0        1
# 8  2025          0        1
# 9  2025          0        1
#
#                                           reply_text  \
# 0  Hi! Thanks for the 5* review, we're so glad to...
# 1  Hey there! All feedback is greatly appreciated...
# 2  Hello Karen, thanks for the great feedback and...
# 3  We would need a bit more information about the...
# 4       Many thanks for your 5 star review.\n^ES ^ES
# 5  Hello. Thanks for leaving a great review. Have...
# 6  Hey there! Thanks for sharing. All feedback is...
# 7  Hi there! We're sorry to hear this. We'll need...
# 8  Hi there, this is what we like to hear! Thank ...
# 9  Hi there! Thanks for leaving such lovely comme...
#
#                                     reply_text_clean           reply_date  \
# 0  hi thanks for the 5 review were so glad to rea...  2025-09-04 14:40:12
# 1  hey there all feedback is greatly appreciated ...  2024-04-29 14:16:29
# 2  hello karen thanks for the great feedback and ...  2025-09-04 13:32:12
# 3  we would need a bit more information about the...  2025-09-04 13:36:37
# 4           many thanks for your 5 star review es es  2025-09-04 12:47:38
# 5  hello thanks for leaving a great review have a...  2025-09-04 10:45:41
# 6  hey there thanks for sharing all feedback is g...  2025-09-04 10:00:10
# 7  hi there were sorry to hear this well need to ...  2025-09-04 08:59:15
# 8  hi there this is what we like to hear thank yo...  2025-09-04 09:57:35
# 9  hi there thanks for leaving such lovely commen...  2025-09-04 09:03:17
#
#    time_to_reply(h)  app_version_head app_version_detail  review_sentiment  \
# 0              0.32               5.0               24.0            0.8012
# 1         -11831.33               5.0               24.0           -0.8957
# 2              0.08               5.0               24.0            0.7906
# 3              0.17               5.0               22.0            0.0000
# 4              0.17               5.0               24.0            0.4927
# 5              0.33               5.0               24.0            0.4404
# 6              0.67               5.0               25.0            0.6249
# 7             -0.34               5.0               24.0           -0.6330
# 8              0.82               5.0               24.0            0.7227
# 9              0.07               5.0               24.0            0.4404
#
#   review_sentiment_label  Consistent  reply_sentiment reply_sentiment_label  \
# 0               positive           1           0.7761              positive
# 1               negative           1           0.8858              positive
# 2               positive           1           0.9100              positive
# 3                neutral           1           0.4588              positive
# 4               positive           1           0.4404              positive
# 5               positive           1           0.8689              positive
# 6               positive           1           0.8908              positive
# 7               negative           1           0.5228              positive
# 8               positive           1           0.9042              positive
# 9               positive           1           0.7717              positive
#
#                                   review_extra_clean  topic_id_ALL  \
# 0            very easy to use app very happy with it            -1
# 1  new <num> app is slow to open too much whitesp...             5
# 2                                  easy to use great            -1
# 3             having issues with your updates advice             5
# 4                                     so easy to use            -1
# 5                                               easy            -1
# 6  it would be a lot better if the balance widget...             2
# 7  having changed a savings account name which wa...             1
# 8  they put the widget back all is right with the...             2
# 9                                        easy to use            -1
#
#                             topic_label_ALL  topic_prob_ALL  topic_id_NEG  \
# 0                                 Undefined        0.000000           NaN
# 1        Transactions, Features & Usability        0.601978           NaN
# 2                                 Undefined        0.000000           NaN
# 3        Transactions, Features & Usability        0.713743           1.0
# 4                                 Undefined        0.000000           NaN
# 5                                 Undefined        0.000000           NaN
# 6  Login, Navigation & Functionality Issues        0.660740           NaN
# 7            Updates, Crashes & Performance        0.373506           NaN
# 8  Login, Navigation & Functionality Issues        0.933764           NaN
# 9                                 Undefined        0.000000           NaN
#
#     topic_label_NEG  topic_prob_NEG  topic_id_POS  \
# 0              <NA>             NaN           NaN
# 1              <NA>             NaN           NaN
# 2              <NA>             NaN           NaN
# 3  Payments & Cards        0.719216           NaN
# 4              <NA>             NaN           NaN
# 5              <NA>             NaN           NaN
# 6              <NA>             NaN           NaN
# 7              <NA>             NaN           NaN
# 8              <NA>             NaN           1.0
# 9              <NA>             NaN           NaN
#
#                     topic_label_POS  topic_prob_POS
# 0                              <NA>             NaN
# 1                              <NA>             NaN
# 2                              <NA>             NaN
# 3                              <NA>             NaN
# 4                              <NA>             NaN
# 5                              <NA>             NaN
# 6                              <NA>             NaN
# 7                              <NA>             NaN
# 8  Features, Security, Transactions        0.929608
# 9                              <NA>             NaN

# %% [markdown]
# ## 4.3. - Analysis of the Results

# %% [markdown]
# ### 4.3.1. - All reviews model

# %% [markdown]
# 1️⃣ **Coherence sanity check** by evaluating a sample of reviews / labels

# %%
def sample_reviews_by_topic(
    df,
    n: int = 5,
    seed: int = 40,
    topic_col: str = "topic_id_ALL",
    label_col: str = "topic_label_ALL",
    prob_col: str = "topic_prob_ALL",
    text_col: str = "review_text",
    score_col: str = "score",
    sentiment_col: str = "review_sentiment_label",
):
    """
    For each topic, sample up to n rows and return a small table with:
      topic_id, topic_label, sample_text, score (if present), sentiment (if present)
    """
    if topic_col not in df.columns:
        raise KeyError(f"Missing column: {topic_col}")
    if text_col not in df.columns:
        raise KeyError(f"Missing column: {text_col}")

    rows = []
    for tid, g in df.dropna(subset=[topic_col]).groupby(topic_col):
        label = g[label_col].iloc[0] if label_col in g.columns else f"Topic {tid}"
        take = min(n, len(g))
        samp = g.sample(take, random_state=seed + int(tid))[[prob_col] + [text_col] + ([score_col] if score_col in g.columns else []) + ([sentiment_col] if sentiment_col in g.columns else [])]

        for idx, r in samp.iterrows():
            rec = {
                "topic_id": tid,
                "topic_label": label,
                "topic_prob": (r[prob_col] if prob_col in samp.columns else None),
                "sample_text": r[text_col],
            }
            if score_col in samp.columns:
                rec["score"] = r[score_col]
            if sentiment_col in samp.columns:
                rec["sentiment"] = r[sentiment_col]
            rows.append(rec)

    out = pd.DataFrame(rows).sort_values(["topic_id"]).reset_index(drop=True)
    return out

# %%
samples_df = sample_reviews_by_topic(df_final, topic_col= "topic_id_ALL",label_col= "topic_label_ALL", prob_col = "topic_prob_ALL", n=5, seed=40)
with pd.option_context('display.max_colwidth', None, 'display.width', None):
    display(samples_df)
# Out:
#     topic_id                               topic_label  topic_prob  \
# 0         -1                                 Undefined    0.000000
# 1         -1                                 Undefined    0.000000
# 2         -1                                 Undefined    0.000000
# 3         -1                                 Undefined    0.000000
# 4         -1                                 Undefined    0.000000
# 5          0                   Fees & Service & Travel    0.479207
# 6          0                   Fees & Service & Travel    0.571331
# 7          0                   Fees & Service & Travel    0.478592
# 8          0                   Fees & Service & Travel    0.392996
# 9          0                   Fees & Service & Travel    0.680610
# 10         1            Updates, Crashes & Performance    0.523796
# 11         1            Updates, Crashes & Performance    0.571261
# 12         1            Updates, Crashes & Performance    0.914273
# 13         1            Updates, Crashes & Performance    0.828357
# 14         1            Updates, Crashes & Performance    0.374377
# 15         2  Login, Navigation & Functionality Issues    0.381180
# 16         2  Login, Navigation & Functionality Issues    0.509721
# 17         2  Login, Navigation & Functionality Issues    0.571429
# 18         2  Login, Navigation & Functionality Issues    0.663099
# 19         2  Login, Navigation & Functionality Issues    0.625674
# 20         3      Money Transfers & Payment Management    0.571426
# 21         3      Money Transfers & Payment Management    0.571427
# 22         3      Money Transfers & Payment Management    0.471669
# 23         3      Money Transfers & Payment Management    0.571220
# 24         3      Money Transfers & Payment Management    0.785485
# 25         4                          Support & Access    0.756755
# 26         4                          Support & Access    0.713912
# 27         4                          Support & Access    0.366845
# 28         4                          Support & Access    0.871073
# 29         4                          Support & Access    0.553808
# 30         5        Transactions, Features & Usability    0.572040
# 31         5        Transactions, Features & Usability    0.713706
# 32         5        Transactions, Features & Usability    0.675912
# 33         5        Transactions, Features & Usability    0.713888
# 34         5        Transactions, Features & Usability    0.571008
# 35         6                          Cards & Payments    0.785714
# 36         6                          Cards & Payments    0.407558
# 37         6                          Cards & Payments    0.570794
# 38         6                          Cards & Payments    0.571309
# 39         6                          Cards & Payments    0.571429
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            sample_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Super
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I'm very satisfied
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Works well
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Won't update
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Super
# 5                                                                                                                                                                                                                                                                                                                                              Hands down the worst bank and app I've ever used. Nothing works, they limit withdrawing your money when you set an account up and the online banking doesn't even work.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Love it, give more crypto quizzes more often
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fabulous, even opened one for my granddaughter
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                            As a fairly new customer So far So good..
# 9                                                                                                                                                                                                                                                                                                                                      unreal. I have friends living in northern Ireland saving a fortune using this app to convert money they earn in the republic of Ireland. a great app to go travelling with also
# 10                                                                                                                                                                                                                                                                                                                                                                                                      Best banking mobile app. Very easy and simple to use but secure. No probs on my Android after the last update.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Doesn't work ! Can't log in. Rubbish.
# 12                                                                                                                                                                                                                                                                                                                                                                                                          App has stopped working after updating phone to android 10 on a Pixel 3a, which isn't a beta release... :/
# 13                                                                                                                                                                                                                                                                                                                                                                                                                   This app just stopped working, I go to open it and my phone restarts, only just started happening
# 14                                                                                                                                                                                                                                                                                                                                                       Spending feature doesn't work in app, constantly receive error messages and crashes. Spoken to staff on live chat whom seem disinterested, very disappointing
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                   A good app...works well and I feel safe using it!
# 16                                                                                                                                                                                                                                                                                                                                                         Pretty solid banking app. Feels secure. Linking external bank accounts feature doesn't have a very extensive list, would like to see more options on there.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Very easy to use, speedy and clear.
# 18                                                                                                                                                                                                                                              New redesigned app is just terrible. You need to go through twice as much menus as before because everything was split and hidden behind subcategories, even the history. Like what's the point of displaying just last transaction and leaving rest of display blank?
# 19                                                                                                                                                                                                                                                                                                              Really good app. Straightforward and great functionality. Review edit (23/07/34) have been using Barclays app for over 5 years. Very few issues, manage 99% of my needs through it. Still a great app!
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Very simple and secure app
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Easiest banking app
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Totally great app.  Keeps you updated on your money
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                No complaints at all
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                            simple to use, secure payments. love it.
# 25                                                                                                                                                                                                                                                                                                                            Took just 5 minutes to sign up and send a €250 payment to a Spanish bank \naccount. Fantastic experience so far, especially the few minutes it took to \nverify my ID. Highly recommend!
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                         I don't know how you managed to misspell my surname though!
# 27                                                                                                                                                                                                                                                                                                                               hi its my most favourite app but unfortunately as I downloaded in my new phone set,I can't do contactless payments neither cant find any option inside app... please help me for that
# 28  Accidentally logged out and u can't even log in back despite knowing your own passcode and therefore makes you think u forgot it. So, selected "forgot passcode" and it takes me to another page asking me for verification via email, text or can't access both. Clicked through mail and thought it'll be enough but still goes back to the app and bugged out. I kept receiving blank screen whenever I do this process and it's going nowhere. Managed to talk to 2 Agents but it's the same outcome. FIX ASAP
# 29                                                                                                                                                                                                                                                                                                                                                                                                                  what have you done to this app hsbc?? chat feature doesn't work at all - where do we go from here?
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                           It works, very happy as never had a problem logging into.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Great for group events, collections etc.
# 32                                                                                                                                                                                                                                                                                                                                                                                                         Barclays constantly take on board customer feedback and adjust the app accordingly. Would highly recommend.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                       So much better than other local / traditional banks I've used
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Clear and easy to use far better than halifax
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       user friendly
# 36  Rating updated // Surely you should be able to make repayments on your credit card balance with a few clicks in 2020.. But no, I had a 10 min online chat where I was told that I can't make a transfer within my own account, instead I need to make a payment to a separate business account by typing HSBC and then from the drop down select the account that matches the first 6 digits of my credit card, and to make sure it goes to the right place I need to type in my full card number as a reference??
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Good company👍👍👍👍
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Monzo card
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Easy-to-use
#
#     score sentiment
# 0       5  positive
# 1       5  positive
# 2       5  positive
# 3       1   neutral
# 4       5  positive
# 5       1  negative
# 6       5  positive
# 7       5  positive
# 8       5  positive
# 9       5  positive
# 10      5  positive
# 11      2   neutral
# 12      2  negative
# 13      2  negative
# 14      1  negative
# 15      5  positive
# 16      4  positive
# 17      5  positive
# 18      1  negative
# 19      5  positive
# 20      5  positive
# 21      5  positive
# 22      5  positive
# 23      5  positive
# 24      5  positive
# 25      5  positive
# 26      5   neutral
# 27      5  positive
# 28      2  negative
# 29      1   neutral
# 30      5  positive
# 31      5  positive
# 32      5  positive
# 33      5  positive
# 34      5  positive
# 35      5  positive
# 36      4  positive
# 37      5  positive
# 38      4   neutral
# 39      5   neutral

# %% [markdown]
# 2️⃣ **Topic distribution per type of sentiment**

# %%
topic_sent = (df_final.groupby(["topic_id_ALL","topic_label_ALL","review_sentiment_label"])
                        .size().unstack(fill_value=0))
topic_sent['total'] = topic_sent['negative']+topic_sent['neutral']+topic_sent['positive']
topic_sent["share_neg"] = topic_sent.get("negative",0) / topic_sent.sum(axis=1)
topic_sent["share_pos"] = topic_sent.get("positive",0) / topic_sent.sum(axis=1)
topic_sent.sort_values('topic_id_ALL', ascending=True)
# Out:
# review_sentiment_label                                 negative  neutral  \
# topic_id_ALL topic_label_ALL
# -1           Undefined                                    22820    41795
#  0           Fees & Service & Travel                       4085     9081
#  1           Updates, Crashes & Performance               18582    15325
#  2           Login, Navigation & Functionality Issues      5214     8584
#  3           Money Transfers & Payment Management          3250     5730
#  4           Support & Access                             19637    11386
#  5           Transactions, Features & Usability            5124     8470
#  6           Cards & Payments                              3200     4197
#
# review_sentiment_label                                 positive  undefined  \
# topic_id_ALL topic_label_ALL
# -1           Undefined                                   316544       4159
#  0           Fees & Service & Travel                      63434          0
#  1           Updates, Crashes & Performance               30029          0
#  2           Login, Navigation & Functionality Issues     43222          0
#  3           Money Transfers & Payment Management         53447          0
#  4           Support & Access                             34940          0
#  5           Transactions, Features & Usability           44881          0
#  6           Cards & Payments                             35967          0
#
# review_sentiment_label                                  total  share_neg  \
# topic_id_ALL topic_label_ALL
# -1           Undefined                                 381159   0.029773
#  0           Fees & Service & Travel                    76600   0.026664
#  1           Updates, Crashes & Performance             63936   0.145317
#  2           Login, Navigation & Functionality Issues   57020   0.045721
#  3           Money Transfers & Payment Management       62427   0.026030
#  4           Support & Access                           65963   0.148849
#  5           Transactions, Features & Usability         58475   0.043814
#  6           Cards & Payments                           43364   0.036897
#
# review_sentiment_label                                 share_pos
# topic_id_ALL topic_label_ALL
# -1           Undefined                                  0.412986
#  0           Fees & Service & Travel                    0.414060
#  1           Updates, Crashes & Performance             0.234836
#  2           Login, Navigation & Functionality Issues   0.379007
#  3           Money Transfers & Payment Management       0.428076
#  4           Support & Access                           0.264845
#  5           Transactions, Features & Usability         0.383762
#  6           Cards & Payments                           0.414710

# %% [markdown]
# 3️⃣ **Topic distribution per app and scores**

# %%
# Keep only rows where topic_label_ALL is not 'Undefined'
df_sub = df_final[df_final["topic_label_ALL"] != "Undefined"].copy()

# define topics, apps and colors
topics = sorted(df_sub['topic_label_ALL'].dropna().unique())
apps   = sorted(df_sub['app'].dropna().unique())

palette = plt.get_cmap('tab20').colors
topic_color = {t: palette[i % len(palette)] for i, t in enumerate(topics)}

def topic_share_by_app(df, score, label_col= 'topic_label_ALL', min_reviews=0):
    tmp = (df[df['score'].isin(score)]
             .dropna(subset=[label_col,'app'])
             .groupby(['app',label_col])
             .size()
             .unstack(fill_value=0))
    tmp = tmp.reindex(index=apps, columns=topics, fill_value=0)

    totals = tmp.sum(axis=1)
    if min_reviews > 0:
        tmp = tmp.loc[totals >= min_reviews]
        totals = tmp.sum(axis=1)

    shares = tmp.div(totals.replace(0, np.nan), axis=0).fillna(0)
    return shares, totals

def plot_stacked(shares, totals, title, label_threshold=0.04):
    ax = shares.plot(
        kind='bar', stacked=True, figsize=(14,6), width=0.85,
        color=[topic_color[t] for t in shares.columns]
    )
    ax.set_title(title)
    ax.set_xlabel('App / Bank')
    ax.set_ylabel('Proportion of reviews')
    ax.set_ylim(0, 1.08)
    ax.set_title(title, pad=10)  
    ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f"{y:.0%}"))
    ax.legend(title='Topic', bbox_to_anchor=(1.02, 1), loc='upper left')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

    # --- % labels inside segments ---
    for i, (_, row) in enumerate(shares.iterrows()):
        cum = 0.0
        for t in shares.columns:
            v = float(row[t])
            if v > 0:
                if v >= label_threshold:  # avoid clutter for tiny slices
                    ax.text(
                        i, cum + v/2, f"{v:.0%}",
                        ha='center', va='center',
                        fontsize=8,
                        color='black'
                    )
                cum += v

    # --- show n on top of each bar ---
    for i, n in enumerate(totals.loc[shares.index]):
        ax.text(i, 1.01, f"n={int(n)}", ha='center', va='bottom', fontsize=8)

    plt.tight_layout()
    plt.show()

# --- build data & plot ---
pos_shares, pos_totals = topic_share_by_app(df_sub, score = [4,5], label_col= 'topic_label_ALL', min_reviews=0)
neg_shares, neg_totals = topic_share_by_app(df_sub, score = [1,2], label_col= 'topic_label_ALL', min_reviews=0)

plot_stacked(pos_shares, pos_totals, "Topic mix by app — Positive reviews")
plot_stacked(neg_shares, neg_totals, "Topic mix by app — Negative reviews")

# %% [markdown]
# ### 4.3.2. - Negative reviews model

# %% [markdown]
# 1️⃣ **Coherence sanity check** by evaluating a sample of reviews / labels

# %%
samples_df = sample_reviews_by_topic(df_final, topic_col= "topic_id_NEG",label_col= "topic_label_NEG", n=5, seed=40)
with pd.option_context('display.max_colwidth', None, 'display.width', None):
    display(samples_df)
# Out:
#     topic_id                 topic_label  topic_prob  \
# 0        0.0            Login & Security    0.892644
# 1        0.0            Login & Security    0.459309
# 2        0.0            Login & Security    0.828400
# 3        0.0            Login & Security    0.901691
# 4        0.0            Login & Security    0.914189
# 5        1.0            Payments & Cards    0.439432
# 6        1.0            Payments & Cards    0.571429
# 7        1.0            Payments & Cards    0.571341
# 8        1.0            Payments & Cards    0.692500
# 9        1.0            Payments & Cards    0.498629
# 10       2.0       App Updates & Crashes    0.571428
# 11       2.0       App Updates & Crashes    0.709462
# 12       2.0       App Updates & Crashes    0.856867
# 13       2.0       App Updates & Crashes    0.535241
# 14       2.0       App Updates & Crashes    0.592467
# 15       3.0     Transfers & Transaction    0.628009
# 16       3.0     Transfers & Transaction    0.744678
# 17       3.0     Transfers & Transaction    0.753668
# 18       3.0     Transfers & Transaction    0.639302
# 19       3.0     Transfers & Transaction    0.454652
# 20       4.0  Interface, Features & Fees    0.571311
# 21       4.0  Interface, Features & Fees    0.627980
# 22       4.0  Interface, Features & Fees    0.702732
# 23       4.0  Interface, Features & Fees    0.705105
# 24       4.0  Interface, Features & Fees    0.626257
# 25       5.0  Customer Service & Support    0.571408
# 26       5.0  Customer Service & Support    0.558990
# 27       5.0  Customer Service & Support    0.528117
# 28       5.0  Customer Service & Support    0.877362
# 29       5.0  Customer Service & Support    0.732699
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   sample_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                   Doesn't work for my sony ericsson xperia. Tried to install twice and I just get a white and green screen.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Don't work at all , I can't login always asking to trying again.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                        After update very slow loading app and acounds. Take more of 10 sec.
# 3                                                                                                      Just updated Android and now this app doesn't work at all won't even open up !!! Come on Barclay's sort it out or you will lose many customers !. UPDATE  spoken to Barclay's countless times STILL they cannot update the app to work with latest android 7 os .  Come on Barclay's sort it out before you lose more customers !! . Note to Barclay's ...Apps DO NOT take this long to fix !!  DO YOUR JOBS PROPERLY AND FIX THIS APP
# 4                                                                                                                                                                                                                                                                                                                                                                                                          Crashes every time by logging out as soon as logged in. So buggy it's \nimpossible to use. Used to be fine, now a waste of memory.
# 5                                                                                                                                                                                                                                                                Would be really useful to have a running balance against the transactions. Never know if all the payments have been taken out of the current balance. there are issues if you have more than one account, needs to be more like the normal online banking. Moving money etc.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Does not work. Keeps crashing.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Not usable when rooted.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                              The app is really sluggish compared to other banking apps and it's not the easiest to navigate
# 9                                                                                                                                                                                                                                                                                                                                                                                                 most pointless app in the world if you dont bank directly with them. i have a credit card account and can literally just look at the amount
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    New update doesn't work
# 11                                                                                                                                                                                                                                                                                                                                                                                                                    Service Unavailable , This service is temporarily unavailable please try again later. From last two weeks same message.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Can't download any statements just keep being told there corrupt
# 13                                                                                                                                                                                                                                                                                                                                                                                                                               What's wrong with this app this morning it won't open just keeps shutting \ndown anyone else having problems
# 14                                                                                                                                                                                                                                                                                                                                                                                  Usually a really good app but for the past 2 to 3 weeks it has been running really slow, very much like waiting for a dial up modem to connect. Nightmare
# 15                                                                                                                                                                                                                                                          My account got frozen when I want to make a payment. I don't know what's wrong with it but this is very disappointing. I cannot do anything but wait for their investigation, while I need to pay rent in few days. After this problem is solved, surely I will close my account.
# 16                                                                                                                                                                                                                                                                                                                                                                                          Misleading. At the beginning it was all rainbows and unicorns bot now a lot of taxes or restrictions are present at almost any action on the app.
# 17                                                                                                                                                                                                                                                             Very bad experince with this bank they block my account and ask for some documant then when i approved everthing my accout still not working and the support team all what they know is sorry and no information to provide Think twice before put your money inisde this bank
# 18                                                                                                                                                                                                                                                                                                                                                                                     It's good for checking your money but it has maintenance like twice to three times a week so you cant buy anything online and it gets really annoying.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Referal links don't work, you don't get any extra funds.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  very slow old app better dont like layout
# 21                                                                                                                                                                                                                                                                    Unworkable app with no provision to use multiple accounts as previously possible, so now unable to access our second account!!!! Visually inferior gui with masses of wasted space... If you cannot fix it, at least make the previous version available. Disgraceful!!
# 22                                                                                                                                                                            Was all ok until the issues with Android 10 texts started arriving. Now i am forced to choose access to my accounts on the go or the security of my phone's OS. The final build of Android 10 was released to app makers and modifiers months ago, so why is the Barclays app not capable of working on the latest OS? Very disappointing from a big tech team.
# 23                                                                                                                                                                                                                                                                                                                                 Second time now in a month accounts keep disappearing from the app brought it to Barclays attention and it was fixed now doing it again! Sort it please! Was fixed since my last review now missing again!
# 24                                                                                                                                                                                                                                                                                                                                         Worst app, worse support. The people running revolut are so incompetent you'll end up losing your money before you actually benefit from their services. Close your account and run for the woods.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Doesn't let me verify anything do it's a useless app.
# 26  I lost access to this app when i upgraded my phone's software in February. Since then despite saying that the issue has been upgraded to a priority level there is no solution and i was told last time i spent 30 minutes on the phone trying to get an update that it was not Barclays problem. Beware this app doesn't work on all phones (mine's a Huawei) and Barclays have charging policies that increase on some accounts if you use telephone banking and not via online or mobile.  Very disappointing response from tech team.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                           Can't use my card in shops or ATMs and nobody gets back to my requests for help.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                       Very slow and very hard to get a response from when you have a problem or need help, I wouldn't recommend this bank.
# 29                                                                                                                                                                                                                                                                                                                                                     Disappointingly this app declined both my cards, one a mastercard debit card (virgin money) and the other a visa cash card with Lloyds. Both had more than sufficient funds available.
#
#     score sentiment
# 0       1   neutral
# 1       1   neutral
# 2       1   neutral
# 3       1  negative
# 4       1  negative
# 5       1  positive
# 6       1   neutral
# 7       1   neutral
# 8       2  negative
# 9       1  positive
# 10      1   neutral
# 11      1  positive
# 12      1   neutral
# 13      1  negative
# 14      2  positive
# 15      1  negative
# 16      1  negative
# 17      1  negative
# 18      2   neutral
# 19      1   neutral
# 20      2  positive
# 21      1  negative
# 22      2  negative
# 23      1   neutral
# 24      1  negative
# 25      1  negative
# 26      1  negative
# 27      1  positive
# 28      1  negative
# 29      1  negative

# %% [markdown]
# 2️⃣ **Topic distribution per type of sentiment**

# %%
topic_sent = (df_final.groupby(["topic_id_NEG","topic_label_NEG","score"])
                        .size().unstack(fill_value=0))
topic_sent['total'] = topic_sent[1]+topic_sent[2]
topic_sent.sort_values('topic_id_NEG', ascending=True)
# Out:
# score                                        1     2  total
# topic_id_NEG topic_label_NEG
# 0.0          Login & Security            15408  4582  19990
# 1.0          Payments & Cards             5572  4018   9590
# 2.0          App Updates & Crashes       10693  4773  15466
# 3.0          Transfers & Transaction      7967  1947   9914
# 4.0          Interface, Features & Fees   6787  3007   9794
# 5.0          Customer Service & Support   9711  2060  11771

# %% [markdown]
# 3️⃣ **Topic distribution per app and scores**

# %%
# Keep only rows where topic_label_ALL is not 'Undefined'
df_sub = df_final[df_final["topic_label_NEG"].notna()].copy()

# define topics, apps and colors
topics = sorted(df_sub['topic_label_NEG'].dropna().unique())
apps   = sorted(df_sub['app'].dropna().unique())

palette = plt.get_cmap('tab20').colors
topic_color = {t: palette[i % len(palette)] for i, t in enumerate(topics)}


# --- build data & plot ---
neg_shares, neg_totals = topic_share_by_app(df_sub, score = [1,2], label_col= 'topic_label_NEG', min_reviews=0)
plot_stacked(neg_shares, neg_totals, "Topic mix by app — Negative reviews")

# %% [markdown]
# ### 4.3.3. - Positive reviews model

# %% [markdown]
# 1️⃣ **Coherence sanity check** by evaluating a sample of reviews / labels

# %%
samples_df = sample_reviews_by_topic(df_final, topic_col= "topic_id_ALL",label_col= "topic_label_ALL", n=5, seed=40)
with pd.option_context('display.max_colwidth', None, 'display.width', None):
    display(samples_df)
# Out:
#     topic_id                               topic_label  topic_prob  \
# 0         -1                                 Undefined    0.000000
# 1         -1                                 Undefined    0.000000
# 2         -1                                 Undefined    0.000000
# 3         -1                                 Undefined    0.000000
# 4         -1                                 Undefined    0.000000
# 5          0                   Fees & Service & Travel    0.479207
# 6          0                   Fees & Service & Travel    0.571331
# 7          0                   Fees & Service & Travel    0.478592
# 8          0                   Fees & Service & Travel    0.392996
# 9          0                   Fees & Service & Travel    0.680610
# 10         1            Updates, Crashes & Performance    0.523796
# 11         1            Updates, Crashes & Performance    0.571261
# 12         1            Updates, Crashes & Performance    0.914273
# 13         1            Updates, Crashes & Performance    0.828357
# 14         1            Updates, Crashes & Performance    0.374377
# 15         2  Login, Navigation & Functionality Issues    0.381180
# 16         2  Login, Navigation & Functionality Issues    0.509721
# 17         2  Login, Navigation & Functionality Issues    0.571429
# 18         2  Login, Navigation & Functionality Issues    0.663099
# 19         2  Login, Navigation & Functionality Issues    0.625674
# 20         3      Money Transfers & Payment Management    0.571426
# 21         3      Money Transfers & Payment Management    0.571427
# 22         3      Money Transfers & Payment Management    0.471669
# 23         3      Money Transfers & Payment Management    0.571220
# 24         3      Money Transfers & Payment Management    0.785485
# 25         4                          Support & Access    0.756755
# 26         4                          Support & Access    0.713912
# 27         4                          Support & Access    0.366845
# 28         4                          Support & Access    0.871073
# 29         4                          Support & Access    0.553808
# 30         5        Transactions, Features & Usability    0.572040
# 31         5        Transactions, Features & Usability    0.713706
# 32         5        Transactions, Features & Usability    0.675912
# 33         5        Transactions, Features & Usability    0.713888
# 34         5        Transactions, Features & Usability    0.571008
# 35         6                          Cards & Payments    0.785714
# 36         6                          Cards & Payments    0.407558
# 37         6                          Cards & Payments    0.570794
# 38         6                          Cards & Payments    0.571309
# 39         6                          Cards & Payments    0.571429
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            sample_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Super
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I'm very satisfied
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Works well
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Won't update
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Super
# 5                                                                                                                                                                                                                                                                                                                                              Hands down the worst bank and app I've ever used. Nothing works, they limit withdrawing your money when you set an account up and the online banking doesn't even work.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Love it, give more crypto quizzes more often
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Fabulous, even opened one for my granddaughter
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                            As a fairly new customer So far So good..
# 9                                                                                                                                                                                                                                                                                                                                      unreal. I have friends living in northern Ireland saving a fortune using this app to convert money they earn in the republic of Ireland. a great app to go travelling with also
# 10                                                                                                                                                                                                                                                                                                                                                                                                      Best banking mobile app. Very easy and simple to use but secure. No probs on my Android after the last update.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Doesn't work ! Can't log in. Rubbish.
# 12                                                                                                                                                                                                                                                                                                                                                                                                          App has stopped working after updating phone to android 10 on a Pixel 3a, which isn't a beta release... :/
# 13                                                                                                                                                                                                                                                                                                                                                                                                                   This app just stopped working, I go to open it and my phone restarts, only just started happening
# 14                                                                                                                                                                                                                                                                                                                                                       Spending feature doesn't work in app, constantly receive error messages and crashes. Spoken to staff on live chat whom seem disinterested, very disappointing
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                   A good app...works well and I feel safe using it!
# 16                                                                                                                                                                                                                                                                                                                                                         Pretty solid banking app. Feels secure. Linking external bank accounts feature doesn't have a very extensive list, would like to see more options on there.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Very easy to use, speedy and clear.
# 18                                                                                                                                                                                                                                              New redesigned app is just terrible. You need to go through twice as much menus as before because everything was split and hidden behind subcategories, even the history. Like what's the point of displaying just last transaction and leaving rest of display blank?
# 19                                                                                                                                                                                                                                                                                                              Really good app. Straightforward and great functionality. Review edit (23/07/34) have been using Barclays app for over 5 years. Very few issues, manage 99% of my needs through it. Still a great app!
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Very simple and secure app
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Easiest banking app
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Totally great app.  Keeps you updated on your money
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                No complaints at all
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                            simple to use, secure payments. love it.
# 25                                                                                                                                                                                                                                                                                                                            Took just 5 minutes to sign up and send a €250 payment to a Spanish bank \naccount. Fantastic experience so far, especially the few minutes it took to \nverify my ID. Highly recommend!
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                         I don't know how you managed to misspell my surname though!
# 27                                                                                                                                                                                                                                                                                                                               hi its my most favourite app but unfortunately as I downloaded in my new phone set,I can't do contactless payments neither cant find any option inside app... please help me for that
# 28  Accidentally logged out and u can't even log in back despite knowing your own passcode and therefore makes you think u forgot it. So, selected "forgot passcode" and it takes me to another page asking me for verification via email, text or can't access both. Clicked through mail and thought it'll be enough but still goes back to the app and bugged out. I kept receiving blank screen whenever I do this process and it's going nowhere. Managed to talk to 2 Agents but it's the same outcome. FIX ASAP
# 29                                                                                                                                                                                                                                                                                                                                                                                                                  what have you done to this app hsbc?? chat feature doesn't work at all - where do we go from here?
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                           It works, very happy as never had a problem logging into.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Great for group events, collections etc.
# 32                                                                                                                                                                                                                                                                                                                                                                                                         Barclays constantly take on board customer feedback and adjust the app accordingly. Would highly recommend.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                       So much better than other local / traditional banks I've used
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Clear and easy to use far better than halifax
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       user friendly
# 36  Rating updated // Surely you should be able to make repayments on your credit card balance with a few clicks in 2020.. But no, I had a 10 min online chat where I was told that I can't make a transfer within my own account, instead I need to make a payment to a separate business account by typing HSBC and then from the drop down select the account that matches the first 6 digits of my credit card, and to make sure it goes to the right place I need to type in my full card number as a reference??
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Good company👍👍👍👍
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Monzo card
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Easy-to-use
#
#     score sentiment
# 0       5  positive
# 1       5  positive
# 2       5  positive
# 3       1   neutral
# 4       5  positive
# 5       1  negative
# 6       5  positive
# 7       5  positive
# 8       5  positive
# 9       5  positive
# 10      5  positive
# 11      2   neutral
# 12      2  negative
# 13      2  negative
# 14      1  negative
# 15      5  positive
# 16      4  positive
# 17      5  positive
# 18      1  negative
# 19      5  positive
# 20      5  positive
# 21      5  positive
# 22      5  positive
# 23      5  positive
# 24      5  positive
# 25      5  positive
# 26      5   neutral
# 27      5  positive
# 28      2  negative
# 29      1   neutral
# 30      5  positive
# 31      5  positive
# 32      5  positive
# 33      5  positive
# 34      5  positive
# 35      5  positive
# 36      4  positive
# 37      5  positive
# 38      4   neutral
# 39      5   neutral

# %% [markdown]
# 2️⃣ **Topic distribution per type of sentiment**

# %%
topic_sent = (df_final.groupby(["topic_id_POS","topic_label_POS","score"])
                        .size().unstack(fill_value=0))
topic_sent['total'] = topic_sent[4]+topic_sent[5]
topic_sent.sort_values('topic_id_POS', ascending=True)
# Out:
# score                                              4      5  total
# topic_id_POS topic_label_POS
# 0.0          Customer Service & Usability       3686  44061  47747
# 1.0          Features, Security, Transactions  10016  46400  56416
# 2.0          Payments, Transfers & Money Mgmt   6769  46246  53015
# 3.0          Investments                        6144  41058  47202
# 4.0          Cards & Travel                     6603  52665  59268
# 5.0          Updates & Support                 14726  43911  58637

# %% [markdown]
# 3️⃣ **Topic distribution per app and scores**

# %%
# Keep only rows where topic_label_ALL is not 'Undefined'
df_sub = df_final[df_final["topic_label_POS"].notna()].copy()

# define topics, apps and colors
topics = sorted(df_sub['topic_label_POS'].dropna().unique())
apps   = sorted(df_sub['app'].dropna().unique())

palette = plt.get_cmap('tab20').colors
topic_color = {t: palette[i % len(palette)] for i, t in enumerate(topics)}


# --- build data & plot ---
pos_shares, pos_totals = topic_share_by_app(df_sub, score = [4,5], label_col= 'topic_label_POS', min_reviews=0)
plot_stacked(pos_shares, pos_totals, "Topic mix by app — Positive reviews")
